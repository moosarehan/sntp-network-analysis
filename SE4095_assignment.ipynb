# %% [markdown]
# # SE4095 Assignment 01 - Reproducible analysis
# Run the following cells in order. The pipeline uses fixed random seeds and writes Parts A-E to their separate output folders.

# %%
from run_all_parts import main
main()

# %% [markdown]
# ## Outputs
# Review `part_a_output`, `part_b_output`, `part_c_output`, `part_d_output`, and `part_e_output`. Read `part_f_reproducibility.md` for the final conclusion and limitations.
